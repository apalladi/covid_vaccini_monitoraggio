# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

plt.style.use('default')

# %% [markdown]
# # Importa dati dell'Istituto Superiore di Sanità
# Questi dati sono ricavati dai bollettini settimanali dell'ISS. Vedi ad esempio https://www.epicentro.iss.it/coronavirus/bollettino/Bollettino-sorveglianza-integrata-COVID-19_15-settembre-2021.pdf

# %%
df_assoluti = pd.read_csv('../dati/dati_ISS_complessivi.csv', sep=';')

df_assoluti
# Out:
#           data  non vaccinati  vaccinati completo  casi non vaccinati  \
# 0   2021-09-22       12581126            36332207               86133
# 1   2021-09-15       13334156            35599815               96900
# 2   2021-09-08       14507530            34292078              104890
# 3   2021-09-01       15656647            32287644              107937
# 4   2021-08-25       16708830            29628678              104405
# 5   2021-08-18       17568325            26501452               95261
# 6   2021-08-11       20322716            22345659               80585
# 7   2021-08-04       21289761            19570464               60267
# 8   2021-07-28       22879167            17389604               40729
# 9   2021-07-21       24745853            15384196               26284
# 10  2021-07-14       27065063            13929401               21089
#
#     casi vaccinati  ospedalizzati non vaccinati  ospedalizzati vaccinati  \
# 0            44050                         6782                     2456
# 1            44990                         6841                     2331
# 2            43775                         6579                     2118
# 3            40380                         5988                     1788
# 4            33894                         5162                     1349
# 5            24978                         4052                      859
# 6            18887                         3067                      627
# 7            12333                         2234                      404
# 8             7277                         1619                      280
# 9             3805                         1483                      224
# 10            2310                         1880                      240
#
#     terapia intensiva non vaccinati  terapia intensiva vaccinati  \
# 0                               775                          173
# 1                               786                          163
# 2                               712                          157
# 3                               641                          127
# 4                               500                           95
# 5                               334                           61
# 6                               247                           34
# 7                               169                           23
# 8                               123                           16
# 9                               117                            8
# 10                              147                            7
#
#     decessi non vaccinati  decessi vaccinati
# 0                     877                509
# 1                     770                405
# 2                     571                280
# 3                     383                187
# 4                     246                 92
# 5                     177                 48
# 6                     143                 34
# 7                     128                 34
# 8                     169                 38
# 9                     250                 46
# 10                    357                 68

# %% [markdown]
# # Elaborazione dati
# Calcola tassi di infezione, ospedalizzazione e decessi per vaccinati e non vaccinati

# %%
# ricava i tassi, dividendo per la popolazione vaccinati e non vaccinata
tassi = (7/30)*10**5*np.transpose([df_assoluti['casi non vaccinati']/df_assoluti['non vaccinati'],
         df_assoluti['casi vaccinati']/df_assoluti['vaccinati completo'],                  
         df_assoluti['ospedalizzati non vaccinati']/df_assoluti['non vaccinati'],
         df_assoluti['ospedalizzati vaccinati']/df_assoluti['vaccinati completo'],
         df_assoluti['terapia intensiva non vaccinati']/df_assoluti['non vaccinati'],
         df_assoluti['terapia intensiva vaccinati']/df_assoluti['vaccinati completo'],
         df_assoluti['decessi non vaccinati']/df_assoluti['non vaccinati'],
         df_assoluti['decessi vaccinati']/df_assoluti['vaccinati completo']])

df_tassi = pd.DataFrame(tassi)
df_tassi.columns = ['Casi, non vaccinati',
                    'Casi, vaccinati',
                    'Ospedalizzati, non vaccinati', 
                    'Ospedalizzati, vaccinati',
                    'In terapia intensiva, non vaccinati',
                    'In terapia intensiva, vaccinati',
                    'Deceduti, non vaccinati',
                    'Deceduti, vaccinati']

df_tassi.index = pd.to_datetime(df_assoluti['data'], format='%Y/%m/%d')

df_tassi
# Out:
#             Casi, non vaccinati  Casi, vaccinati  \
# data
# 2021-09-22           159.744843        28.289868
# 2021-09-15           169.564538        29.487981
# 2021-09-08           168.700898        29.785791
# 2021-09-01           160.860113        29.181442
# 2021-08-25           145.798160        26.692382
# 2021-08-18           126.520694        21.992003
# 2021-08-11            92.522902        19.721802
# 2021-08-04            66.051939        14.704301
# 2021-07-28            41.537497         9.764263
# 2021-07-21            24.783681         5.771074
# 2021-07-14            18.181250         3.869513
#
#             Ospedalizzati, non vaccinati  Ospedalizzati, vaccinati  \
# data
# 2021-09-22                     12.578100                  1.577297
# 2021-09-15                     11.971011                  1.527817
# 2021-09-08                     10.581402                  1.441149
# 2021-09-01                      8.924005                  1.292135
# 2021-08-25                      7.208564                  1.062372
# 2021-08-18                      5.381655                  0.756311
# 2021-08-11                      3.521347                  0.654713
# 2021-08-04                      2.448438                  0.481678
# 2021-07-28                      1.651138                  0.375703
# 2021-07-21                      1.398349                  0.339743
# 2021-07-14                      1.620786                  0.402027
#
#             In terapia intensiva, non vaccinati  \
# data
# 2021-09-22                             1.437338
# 2021-09-15                             1.375415
# 2021-09-08                             1.145152
# 2021-09-01                             0.955292
# 2021-08-25                             0.698234
# 2021-08-18                             0.443601
# 2021-08-11                             0.283591
# 2021-08-04                             0.185222
# 2021-07-28                             0.125442
# 2021-07-21                             0.110322
# 2021-07-14                             0.126732
#
#             In terapia intensiva, vaccinati  Deceduti, non vaccinati  \
# data
# 2021-09-22                         0.111104                 1.626510
# 2021-09-15                         0.106836                 1.347417
# 2021-09-08                         0.106827                 0.918374
# 2021-09-01                         0.091779                 0.570791
# 2021-08-25                         0.074815                 0.343531
# 2021-08-18                         0.053708                 0.235082
# 2021-08-11                         0.035503                 0.164184
# 2021-08-04                         0.027422                 0.140287
# 2021-07-28                         0.021469                 0.172355
# 2021-07-21                         0.012134                 0.235730
# 2021-07-14                         0.011726                 0.307777
#
#             Deceduti, vaccinati
# data
# 2021-09-22             0.326891
# 2021-09-15             0.265451
# 2021-09-08             0.190520
# 2021-09-01             0.135139
# 2021-08-25             0.072452
# 2021-08-18             0.042262
# 2021-08-11             0.035503
# 2021-08-04             0.040537
# 2021-07-28             0.050988
# 2021-07-21             0.069769
# 2021-07-14             0.113908

# %% [markdown]
# Calcola i numeri assoluti (medi, giornalieri) dell'epidemia

# %%
df_assoluti2 = df_assoluti.copy(deep=True)
df_assoluti2.index = pd.to_datetime(df_assoluti2['data'], format='%Y/%m/%d')
df_assoluti2.drop('data', axis=1, inplace=True)
# trasforma in numeri settimanali
df_assoluti2 = (1/30)*df_assoluti2

# %% [markdown]
# # Rappresentazione grafica dei risultati

# %% [markdown]
# ### Tassi di infezione, ricovero, decesso

# %%
x_date = ['2021-07-01', '2021-08-01', '2021-09-01']
x_label = ['\nLug \n21', '\nAgo \n21', '\nSet \n21']

def which_axe(x):
    axes[x].set_ylabel('Ogni 100.000 persone per ciascun gruppo')
    axes[x].set_xlabel('')
    axes[x].set_xticks(x_date)
    axes[x].set_xticklabels(x_label)
    axes[x].legend(['Non vaccinati', 'Vaccinati'])
    axes[x].grid()
    
def add_watermark(x):
    axes[x].text(0.5, 0.45, 'Credit: github/apalladi/covid_monitoraggio_vaccini', transform=axes[x].transAxes,
        fontsize=10, color='gray', alpha=0.5,
        ha='center', va='center', rotation=-45)

# %%
fig, axes2 = plt.subplots(nrows=2, ncols=2, figsize=(9, 9))

# unpack all the axes subplots
axes = axes2.ravel()

df_tassi.iloc[:, [0, 1]].plot(ax=axes[0], marker='o')
axes[0].set_title('Incidenza settimanale dei nuovi casi')
which_axe(0)
add_watermark(0)

df_tassi.iloc[:, [2, 3]].plot(ax=axes[1], marker='o')
axes[1].set_title('Incidenza settimanale degli ospedalizzati')
which_axe(1)
add_watermark(1)

df_tassi.iloc[:, [4, 5]].plot(ax=axes[2], marker='o')
axes[2].set_title('Incidenza settimanale dei ricoverati in TI')
which_axe(2)
add_watermark(2)

df_tassi.iloc[:, [6, 7]].plot(ax=axes[3], marker='o')
axes[3].set_title('Incidenza settimanale dei deceduti')
which_axe(3)
add_watermark(3)

plt.tight_layout()
plt.savefig('../risultati/andamento_epidemia.png', dpi=300)
plt.show()

# %% [markdown]
# ### Rapporto fra tassi

# %%
fig = plt.figure(figsize=(6, 5))
(df_tassi.iloc[:, 0]/df_tassi.iloc[:, 1]).plot(label='Nuovi casi', color='blue')
(df_tassi.iloc[:, 2]/df_tassi.iloc[:, 3]).plot(label='Ospedalizzazione', color='green')
(df_tassi.iloc[:, 4]/df_tassi.iloc[:, 5]).plot(label='Ricovero in TI', color='red')
(df_tassi.iloc[:, 6]/df_tassi.iloc[:, 7]).plot(label='Decesso', color='gray')
plt.title('Rapporto fra le incidenze')
plt.legend()
plt.xticks(x_date, x_label)
plt.xlabel('')
plt.ylabel('Non vaccinati/vaccinati')
plt.grid()
fig.text(0.5, 0.5, 'Credit: github/apalladi/covid_monitoraggio_vaccini',# transform=axes[x].transAxes,
        fontsize=14, color='gray', alpha=0.5,
        ha='center', va='center', rotation=-45)  
plt.tight_layout()
plt.savefig('../risultati/rapporto_tra_tassi.png', dpi=300)
plt.show()

# %% [markdown]
# ### Andamento dei numeri assoluti

# %%
x_date = ['2021-07-01', '2021-08-01', '2021-09-01']
x_label = ['\nLug \n21', '\nAgo \n21', '\nSet \n21']

def which_axe(x):
    axes[x].set_xlabel('')
    axes[x].set_xticks(x_date)
    axes[x].set_xticklabels(x_label)
    axes[x].legend(['Non vaccinati', 'Vaccinati'])
    axes[x].grid()

# %%
fig, axes2 = plt.subplots(nrows=2, ncols=2, figsize=(9, 9))

# unpack all the axes subplots
axes = axes2.ravel()

df_assoluti2.iloc[:, [2, 3]].plot(ax=axes[0], marker='o')
axes[0].set_title('Nuovi casi giornalieri \n (media mobile 30 gg)')
which_axe(0)
add_watermark(0)

df_assoluti2.iloc[:, [4, 5]].plot(ax=axes[1], marker='o')
axes[1].set_title('Nuovi ospedalizzati giornalieri \n (media mobile 30 gg)')
which_axe(1)
add_watermark(1)

df_assoluti2.iloc[:, [6, 7]].plot(ax=axes[2], marker='o')
axes[2].set_title('Nuovi ricoverati in TI giornalieri \n (media mobile 30 gg)')
which_axe(2)
add_watermark(2)

df_assoluti2.iloc[:, [8, 9]].plot(ax=axes[3], marker='o')
axes[3].set_title('Decessi giornalieri \n (media mobile 30 gg)')
which_axe(3)
add_watermark(3)

plt.tight_layout()
plt.savefig('../risultati/andamento_epidemia_num_assoluti.png', dpi=300)
plt.show()
