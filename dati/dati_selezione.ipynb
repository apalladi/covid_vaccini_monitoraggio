# %% [markdown]
# ## "Table 3" extraction from ISS weekly covid-19 reports
# https://www.epicentro.iss.it/coronavirus/sars-cov-2-sorveglianza-dati
#
# See example pdf:
# https://www.epicentro.iss.it/coronavirus/bollettino/Bollettino-sorveglianza-integrata-COVID-19_8-settembre-2021.pdf
#
# Requirements: Java 8+, Python 3.6+

# %%
# %%capture
# !pip install tabula-py

# %%
from tabula import read_pdf
import pandas as pd
import numpy as np

# %% [markdown]
# Definizione delle variabili

# %%
# Replace with pdf url
url = 'https://www.epicentro.iss.it/coronavirus/bollettino/Bollettino-sorveglianza-integrata-COVID-19_15-settembre-2021.pdf'
# Replace with report data
rep_date = pd.to_datetime('15/09/2021')
# Replace with index of table of itnerest
table_index = 3

# %%
# Read all tables
raw_tb = read_pdf(url, pages='all', stream=True, silent=True)

# %%
raw_tb[table_index]
# Out:
#              Unnamed: 0     Unnamed: 1  ...      VACCINATI CON     VACCINATI CON.1
# 0                GRUPPO  FASCIA DI ETÀ  ...                NaN                 NaN
# 1                   NaN            NaN  ...   CICLO INCOMPLETO      CICLO COMPLETO
# 2                   NaN          12-39  ...  3.128.125 (17,9%)   7.705.018 (44,2%)
# 3           Popolazione          40-59  ...   1.379.625 (7,5%)  12.382.591 (67,1%)
# 4          (28/08/2021)          60-79  ...     463.925 (3,4%)  11.343.849 (83,6%)
# 5                   NaN            80+  ...     104.255 (2,3%)   4.168.357 (91,5%)
# 6                   NaN          12-39  ...      8.599 (11,1%)      11.700 (15,1%)
# 7           Diagnosi di            NaN  ...                NaN                 NaN
# 8                   NaN          40-59  ...       3.794 (7,7%)      16.554 (33,4%)
# 9            Sars-CoV-2            NaN  ...                NaN                 NaN
# 10         (13/08/2021-          60-79  ...       1.171 (5,5%)      11.620 (54,2%)
# 11          12/09/2021)            80+  ...         164 (2,3%)       5.116 (71,7%)
# 12                  NaN          12-39  ...            76 (4%)          111 (5,9%)
# 13   Ospedalizzazioni**          40-59  ...           116 (4%)          283 (9,7%)
# 14          (6/08/2021-            NaN  ...                NaN                 NaN
# 15           5/09/2021)          60-79  ...         163 (5,7%)         792 (27,7%)
# 16                  NaN            80+  ...          49 (2,6%)       1.145 (60,3%)
# 17  Ricoveri in Terapia          12-39  ...           2 (2,5%)            4 (5,1%)
# 18          Intensiva**          40-59  ...           7 (2,2%)           15 (4,7%)
# 19          (6/08/2021-          60-79  ...          16 (3,4%)          88 (18,7%)
# 20           5/09/2021)            80+  ...           2 (1,8%)          56 (50,9%)
# 21                  NaN          12-39  ...           1 (8,3%)           2 (16,7%)
# 22            Decessi**          40-59  ...           6 (4,4%)          15 (11,1%)
# 23         (23/07/2021-            NaN  ...                NaN                 NaN
# 24          22/08/2021)          60-79  ...          31 (6,4%)         100 (20,7%)
# 25                  NaN            80+  ...          20 (3,3%)         288 (47,8%)
#
# [26 rows x 5 columns]

# %%
# keep the last and the third last column
columns_to_keep = raw_tb[0].columns[[-3,-1]]
to_exclude = '\((.*)|[^a-z-0-9]|\d+-\d+|\d+\+'

df = raw_tb[0][columns_to_keep].replace(to_exclude, '', regex=True).replace('', np.nan)
df = df.dropna(subset=columns_to_keep, how='all').fillna(0).astype(np.int64)
df.columns = ['Non vaccinati', 'Immunizzati']
df
# Out:
#     Non vaccinati  Immunizzati
# 2         6602412      7705018
# 3         4684966     12382591
# 4         1765005     11343849
# 5          281773      4168357
# 6           57228        11700
# 8           29184        16554
# 10           8629        11620
# 11           1859         5116
# 12           1705          111
# 13           2528          283
# 15           1903          792
# 16            705         1145
# 17             73            4
# 18            295           15
# 19            366           88
# 20             52           56
# 21              9            2
# 22            114           15
# 24            353          100
# 25            294          288

# %%
np.arange(0, len(df)-step_+1, step_)
# Out:
# array([ 0,  4,  8, 12, 16])

# %%
# get data
# sum value by age/event

step_ = 4 # groups (=5) are 4 rows (=20) distant (see foo.pdf)

results = [df[col][i:i+step_].sum() for i in np.arange(0, len(df)-step_+1, step_) for col in df.columns]
results
# Out:
# [13334156, 35599815, 96900, 44990, 6841, 2331, 786, 163, 770, 405]

# %%
# Create results_df to merge results
no_vax = pd.Series(results[::2])
yes_vax = pd.Series(results[1::2])
results_df = pd.concat([no_vax, yes_vax], axis=1)
results_df.columns = ['Non vaccinati', 'Immunizzati']
results_df.index = ['Popolazione', 'Diagnosi Sars-CoV-2', 'Ospedalizzazioni', 'Ricoveri in Terapia Intensiva', 'Decessi']
results_df
# Out:
#                                Non vaccinati  Immunizzati
# Popolazione                         13334156     35599815
# Diagnosi Sars-CoV-2                    96900        44990
# Ospedalizzazioni                        6841         2331
# Ricoveri in Terapia Intensiva            786          163
# Decessi                                  770          405

# %%
# read the original general data csv from apalladi's repo
# https://github.com/apalladi/covid_vaccini_monitoraggio/tree/main/dati

date_parser = lambda x: pd.to_datetime(x, format='%Y/%m/%d')
url = 'https://raw.githubusercontent.com/apalladi/covid_vaccini_monitoraggio/main/dati/dati_ISS_complessivi.csv'
df_0 = pd.read_csv(url, sep=';', parse_dates=['data'], date_parser=date_parser, index_col='data')
df_0
# Out:
#             non vaccinati  vaccinati completo  casi non vaccinati  \
# data
# 2021-09-08       14507530            34292078              104890
# 2021-09-01       15656647            32287644              107937
# 2021-08-25       16708830            29628678              104405
# 2021-08-18       17568325            26501452               95261
# 2021-08-11       20322716            22345659               80585
# 2021-08-04       21289761            19570464               60267
# 2021-07-28       22879167            17389604               40729
# 2021-07-21       24745853            15384196               26284
# 2021-07-14       27065063            13929401               21089
#
#             casi vaccinati  ospedalizzati non vaccinati  \
# data
# 2021-09-08           43775                         6579
# 2021-09-01           40380                         5988
# 2021-08-25           33894                         5162
# 2021-08-18           24978                         4052
# 2021-08-11           18887                         3067
# 2021-08-04           12333                         2234
# 2021-07-28            7277                         1619
# 2021-07-21            3805                         1483
# 2021-07-14            2310                         1880
#
#             ospedalizzati vaccinati  terapia intensiva non vaccinati  \
# data
# 2021-09-08                     2118                              712
# 2021-09-01                     1788                              641
# 2021-08-25                     1349                              500
# 2021-08-18                      859                              334
# 2021-08-11                      627                              247
# 2021-08-04                      404                              169
# 2021-07-28                      280                              123
# 2021-07-21                      224                              117
# 2021-07-14                      240                              147
#
#             terapia intensiva vaccinati  decessi non vaccinati  \
# data
# 2021-09-08                          157                    571
# 2021-09-01                          127                    383
# 2021-08-25                           95                    246
# 2021-08-18                           61                    177
# 2021-08-11                           34                    143
# 2021-08-04                           23                    128
# 2021-07-28                           16                    169
# 2021-07-21                            8                    250
# 2021-07-14                            7                    357
#
#             decessi vaccinati
# data
# 2021-09-08                280
# 2021-09-01                187
# 2021-08-25                 92
# 2021-08-18                 48
# 2021-08-11                 34
# 2021-08-04                 34
# 2021-07-28                 38
# 2021-07-21                 46
# 2021-07-14                 68

# %%
# add the new row at the top of the df
df_0.loc[rep_date] = results
df_0.sort_index(ascending=False, inplace=True)
df_0
# Out:
#             non vaccinati  vaccinati completo  casi non vaccinati  \
# data
# 2021-09-15       13334156            35599815               96900
# 2021-09-08       14507530            34292078              104890
# 2021-09-01       15656647            32287644              107937
# 2021-08-25       16708830            29628678              104405
# 2021-08-18       17568325            26501452               95261
# 2021-08-11       20322716            22345659               80585
# 2021-08-04       21289761            19570464               60267
# 2021-07-28       22879167            17389604               40729
# 2021-07-21       24745853            15384196               26284
# 2021-07-14       27065063            13929401               21089
#
#             casi vaccinati  ospedalizzati non vaccinati  \
# data
# 2021-09-15           44990                         6841
# 2021-09-08           43775                         6579
# 2021-09-01           40380                         5988
# 2021-08-25           33894                         5162
# 2021-08-18           24978                         4052
# 2021-08-11           18887                         3067
# 2021-08-04           12333                         2234
# 2021-07-28            7277                         1619
# 2021-07-21            3805                         1483
# 2021-07-14            2310                         1880
#
#             ospedalizzati vaccinati  terapia intensiva non vaccinati  \
# data
# 2021-09-15                     2331                              786
# 2021-09-08                     2118                              712
# 2021-09-01                     1788                              641
# 2021-08-25                     1349                              500
# 2021-08-18                      859                              334
# 2021-08-11                      627                              247
# 2021-08-04                      404                              169
# 2021-07-28                      280                              123
# 2021-07-21                      224                              117
# 2021-07-14                      240                              147
#
#             terapia intensiva vaccinati  decessi non vaccinati  \
# data
# 2021-09-15                          163                    770
# 2021-09-08                          157                    571
# 2021-09-01                          127                    383
# 2021-08-25                           95                    246
# 2021-08-18                           61                    177
# 2021-08-11                           34                    143
# 2021-08-04                           23                    128
# 2021-07-28                           16                    169
# 2021-07-21                            8                    250
# 2021-07-14                            7                    357
#
#             decessi vaccinati
# data
# 2021-09-15                405
# 2021-09-08                280
# 2021-09-01                187
# 2021-08-25                 92
# 2021-08-18                 48
# 2021-08-11                 34
# 2021-08-04                 34
# 2021-07-28                 38
# 2021-07-21                 46
# 2021-07-14                 68

# %%
# save to a csv
df_0.to_csv('dati_ISS_complessivi.csv', sep=';')

# %%
# get data by age
ages = ['12-39', '40-59', '60-79', '80+']
results_ = {age: df[ages.index(age)::step_].stack().values for age in ages}
results_
# Out:
# {'12-39': array([6602412, 7705018,   57228,   11700,    1705,     111,      73,
#               4,       9,       2]),
#  '40-59': array([ 4684966, 12382591,    29184,    16554,     2528,      283,
#              295,       15,      114,       15]),
#  '60-79': array([ 1765005, 11343849,     8629,    11620,     1903,      792,
#              366,       88,      353,      100]),
#  '80+': array([ 281773, 4168357,    1859,    5116,     705,    1145,      52,
#              56,     294,     288])}

# %%
# load dict as df
df_1 = pd.DataFrame(results_).T
df_1.columns = df_0.columns
df_1.index.rename('età', inplace=True)
df_1.head()
# Out:
#        non vaccinati  vaccinati completo  casi non vaccinati  casi vaccinati  \
# età
# 12-39        6602412             7705018               57228           11700
# 40-59        4684966            12382591               29184           16554
# 60-79        1765005            11343849                8629           11620
# 80+           281773             4168357                1859            5116
#
#        ospedalizzati non vaccinati  ospedalizzati vaccinati  \
# età
# 12-39                         1705                      111
# 40-59                         2528                      283
# 60-79                         1903                      792
# 80+                            705                     1145
#
#        terapia intensiva non vaccinati  terapia intensiva vaccinati  \
# età
# 12-39                               73                            4
# 40-59                              295                           15
# 60-79                              366                           88
# 80+                                 52                           56
#
#        decessi non vaccinati  decessi vaccinati
# età
# 12-39                      9                  2
# 40-59                    114                 15
# 60-79                    353                100
# 80+                      294                288

# %%
# save to csv
df_1.to_csv(f'data_iss_età_{rep_date.date()}.csv', sep=';')
