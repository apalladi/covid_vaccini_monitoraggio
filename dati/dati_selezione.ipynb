# %% [markdown]
# ## "Table 3" extraction from ISS weekly covid-19 reports
# https://www.epicentro.iss.it/coronavirus/sars-cov-2-sorveglianza-dati
#
# See example pdf:
# https://www.epicentro.iss.it/coronavirus/bollettino/Bollettino-sorveglianza-integrata-COVID-19_8-settembre-2021.pdf
#
# Requirements: Java 8+, Python 3.6+

# %%
from tabula import read_pdf
import pandas as pd
import numpy as np

# %%
# input file
in_file = 'foo.pdf' # replace with pdf name

# report data
rep_date = '16/09/2021'

# ...and read the raw table
raw_tb = read_pdf(in_file, pages=17, stream=True) # set page containing table 3
raw_tb[0]
# Out:
#              Unnamed: 0 FASCIA DI         Unnamed: 1     VACCINATI CON  \
# 0                GRUPPO       NaN      NON VACCINATI               NaN
# 1                   NaN       ETÀ                NaN  CICLO INCOMPLETO
# 2                   NaN     12-39  7.378.291 (42,3%)   3.129.839 (18%)
# 3           Popolazione     40-59  4.990.358 (27,1%)  1.422.424 (7,7%)
# 4          (21/08/2021)     60-79  1.847.629 (13,6%)    552.988 (4,1%)
# 5                   NaN       80+     291.252 (6,4%)    105.042 (2,3%)
# 6                   NaN     12-39     64.612 (74,6%)    10.267 (11,9%)
# 7           Diagnosi di       NaN                NaN               NaN
# 8            Sars-CoV-2     40-59     29.879 (59,6%)      4.232 (8,4%)
# 9          (06/08/2021-     60-79      8.631 (40,5%)      1.467 (6,9%)
# 10          09/05/2021)       80+      1.768 (26,0%)        163 (2,4%)
# 11                  NaN     12-39      1.711 (89,7%)         92 (4,8%)
# 12   Ospedalizzazioni**     40-59      2.459 (86,6%)        122 (4,3%)
# 13         (30/07/2021-       NaN                NaN               NaN
# 14          29/08/2021)     60-79      1.771 (65,7%)        187 (6,9%)
# 15                  NaN       80+        638 (37,4%)         49 (2,9%)
# 16  Ricoveri in Terapia     12-39         63 (91,3%)          3 (4,3%)
# 17          Intensiva**     40-59        275 (91,7%)          8 (2,7%)
# 18         (30/07/2021-     60-79        331 (75,6%)         16 (3,7%)
# 19          29/08/2021)       80+         43 (46,7%)          3 (3,3%)
# 20                  NaN     12-39          7 (87,5%)         1 (12,5%)
# 21            Decessi**     40-59         85 (82,5%)          8 (7,8%)
# 22         (16/07/2021-       NaN                NaN               NaN
# 23          15/08/2021)     60-79        257 (74,3%)         27 (7,8%)
# 24                  NaN       80+        222 (49,9%)         15 (3,4%)
#
#        VACCINATI CON.1
# 0                  NaN
# 1       CICLO COMPLETO
# 2    6.927.425 (39,7%)
# 3   12.034.678 (65,2%)
# 4   11.172.162 (82,3%)
# 5    4.157.813 (91,3%)
# 6       11.719 (13,5%)
# 7                  NaN
# 8       15.993 (31,9%)
# 9       11.201 (52,6%)
# 10       4.862 (71,6%)
# 11          105 (5,5%)
# 12          258 (9,1%)
# 13                 NaN
# 14         736 (27,3%)
# 15       1.019 (59,7%)
# 16            3 (4,3%)
# 17           17 (5,7%)
# 18          91 (20,8%)
# 19          46 (50,0%)
# 20              0 (0%)
# 21           10 (9,7%)
# 22                 NaN
# 23          62 (17,9%)
# 24         208 (46,7%)

# %%
# keep the last and the third last column
columns_to_keep = [raw_tb[0].columns[-3], raw_tb[0].columns[-1]]

to_exclude = '\((.*)|[^a-z-0-9]|\d+-\d+|\d+\+'
df = raw_tb[0][columns_to_keep].replace(to_exclude, '', regex=True).replace('', np.nan)
df = df.dropna(subset=columns_to_keep, how='all').fillna(0).astype(np.int64)
df.columns = ['Non vaccinati', 'Immunizzati']
df
# Out:
#     Non vaccinati  Immunizzati
# 2         7378291      6927425
# 3         4990358     12034678
# 4         1847629     11172162
# 5          291252      4157813
# 6           64612        11719
# 8           29879        15993
# 9            8631        11201
# 10           1768         4862
# 11           1711          105
# 12           2459          258
# 14           1771          736
# 15            638         1019
# 16             63            3
# 17            275           17
# 18            331           91
# 19             43           46
# 20              7            0
# 21             85           10
# 23            257           62
# 24            222          208

# %%
# get data
# sum value by age/condition

step_ = 4                  # values for age and condition (=5) are 4 rows (=20) distant (see foo.pdf)

results = [df[col][i:i+step_].sum() for i in np.arange(0, len(df)-step_+1, step_) for col in df.columns]
results
# Out:
# [14507530, 34292078, 104890, 43775, 6579, 2118, 712, 157, 571, 280]

# %%
# read the original general data csv from apalladi's repo
# https://github.com/apalladi/covid_vaccini_monitoraggio/tree/main/dati
date_format = '%d/%m/%Y'
date_parser = lambda x: pd.to_datetime(x, format=date_format)
url = 'https://raw.githubusercontent.com/apalladi/covid_vaccini_monitoraggio/main/dati/dati_ISS_complessivi.csv'
df_0 = pd.read_csv(url, sep=';', parse_dates=['data'], date_parser=date_parser, index_col='data')
df_0
# Out:
#             non vaccinati  vaccinati completo  casi non vaccinati  \
# data
# 2021-09-08       14507530            34292078              104890
# 2021-09-01       15656647            32287644              107937
# 2021-08-25       16708830            29628678              104405
# 2021-08-18       17568325            26501452               95261
# 2021-08-11       20322716            22345659               80585
# 2021-08-04       21289761            19570464               60267
# 2021-07-28       22879167            17389604               40729
# 2021-07-21       24745853            15384196               26284
# 2021-07-14       27065063            13929401               21089
#
#             casi vaccinati  ospedalizzati non vaccinati  \
# data
# 2021-09-08           43775                         6579
# 2021-09-01           40380                         5988
# 2021-08-25           33894                         5162
# 2021-08-18           24978                         4052
# 2021-08-11           18887                         3067
# 2021-08-04           12333                         2234
# 2021-07-28            7277                         1619
# 2021-07-21            3805                         1483
# 2021-07-14            2310                         1880
#
#             ospedalizzati vaccinati  terapia intensiva non vaccinati  \
# data
# 2021-09-08                     2118                              712
# 2021-09-01                     1788                              641
# 2021-08-25                     1349                              500
# 2021-08-18                      859                              334
# 2021-08-11                      627                              247
# 2021-08-04                      404                              169
# 2021-07-28                      280                              123
# 2021-07-21                      224                              117
# 2021-07-14                      240                              147
#
#             terapia intensiva vaccinati  decessi non vaccinati  \
# data
# 2021-09-08                          157                    571
# 2021-09-01                          127                    383
# 2021-08-25                           95                    246
# 2021-08-18                           61                    177
# 2021-08-11                           34                    143
# 2021-08-04                           23                    128
# 2021-07-28                           16                    169
# 2021-07-21                            8                    250
# 2021-07-14                            7                    357
#
#             decessi vaccinati
# data
# 2021-09-08                280
# 2021-09-01                187
# 2021-08-25                 92
# 2021-08-18                 48
# 2021-08-11                 34
# 2021-08-04                 34
# 2021-07-28                 38
# 2021-07-21                 46
# 2021-07-14                 68

# %%
# add the new row at the top of the df
df_0.loc[pd.to_datetime(rep_date)] = results
df_0.sort_index(ascending=False, inplace=True)
df_0
# Out:
#             non vaccinati  vaccinati completo  casi non vaccinati  \
# data
# 2021-09-16       14507530            34292078              104890
# 2021-09-08       14507530            34292078              104890
# 2021-09-01       15656647            32287644              107937
# 2021-08-25       16708830            29628678              104405
# 2021-08-18       17568325            26501452               95261
# 2021-08-11       20322716            22345659               80585
# 2021-08-04       21289761            19570464               60267
# 2021-07-28       22879167            17389604               40729
# 2021-07-21       24745853            15384196               26284
# 2021-07-14       27065063            13929401               21089
#
#             casi vaccinati  ospedalizzati non vaccinati  \
# data
# 2021-09-16           43775                         6579
# 2021-09-08           43775                         6579
# 2021-09-01           40380                         5988
# 2021-08-25           33894                         5162
# 2021-08-18           24978                         4052
# 2021-08-11           18887                         3067
# 2021-08-04           12333                         2234
# 2021-07-28            7277                         1619
# 2021-07-21            3805                         1483
# 2021-07-14            2310                         1880
#
#             ospedalizzati vaccinati  terapia intensiva non vaccinati  \
# data
# 2021-09-16                     2118                              712
# 2021-09-08                     2118                              712
# 2021-09-01                     1788                              641
# 2021-08-25                     1349                              500
# 2021-08-18                      859                              334
# 2021-08-11                      627                              247
# 2021-08-04                      404                              169
# 2021-07-28                      280                              123
# 2021-07-21                      224                              117
# 2021-07-14                      240                              147
#
#             terapia intensiva vaccinati  decessi non vaccinati  \
# data
# 2021-09-16                          157                    571
# 2021-09-08                          157                    571
# 2021-09-01                          127                    383
# 2021-08-25                           95                    246
# 2021-08-18                           61                    177
# 2021-08-11                           34                    143
# 2021-08-04                           23                    128
# 2021-07-28                           16                    169
# 2021-07-21                            8                    250
# 2021-07-14                            7                    357
#
#             decessi vaccinati
# data
# 2021-09-16                280
# 2021-09-08                280
# 2021-09-01                187
# 2021-08-25                 92
# 2021-08-18                 48
# 2021-08-11                 34
# 2021-08-04                 34
# 2021-07-28                 38
# 2021-07-21                 46
# 2021-07-14                 68

# %%
# change data index to match the original format
df_0.index = df_0.index.strftime(date_format)

# save to a csv
df_0.to_csv('dati_ISS_complessivi.csv', encoding='utf-8-sig')

# %%
# get data by age
ages = ['12-39', '40-59', '60-79', '80+']
results_ = {age: df[ages.index(age)::step_].stack().values for age in ages}
results_
# Out:
# {'12-39': array([7378291, 6927425,   64612,   11719,    1711,     105,      63,
#               3,       7,       0], dtype=int64),
#  '40-59': array([ 4990358, 12034678,    29879,    15993,     2459,      258,
#              275,       17,       85,       10], dtype=int64),
#  '60-79': array([ 1847629, 11172162,     8631,    11201,     1771,      736,
#              331,       91,      257,       62], dtype=int64),
#  '80+': array([ 291252, 4157813,    1768,    4862,     638,    1019,      43,
#              46,     222,     208], dtype=int64)}

# %%
# load dict as df
df_1 = pd.DataFrame(results_).T
df_1.columns = df_0.columns
df_1.index.rename('età', inplace=True)
df_1.head()
# Out:
#        non vaccinati  vaccinati completo  casi non vaccinati  casi vaccinati  \
# età
# 12-39        7378291             6927425               64612           11719
# 40-59        4990358            12034678               29879           15993
# 60-79        1847629            11172162                8631           11201
# 80+           291252             4157813                1768            4862
#
#        ospedalizzati non vaccinati  ospedalizzati vaccinati  \
# età
# 12-39                         1711                      105
# 40-59                         2459                      258
# 60-79                         1771                      736
# 80+                            638                     1019
#
#        terapia intensiva non vaccinati  terapia intensiva vaccinati  \
# età
# 12-39                               63                            3
# 40-59                              275                           17
# 60-79                              331                           91
# 80+                                 43                           46
#
#        decessi non vaccinati  decessi vaccinati
# età
# 12-39                      7                  0
# 40-59                     85                 10
# 60-79                    257                 62
# 80+                      222                208

# %%
# save to csv
out_date = rep_date.replace('/', '-')
out_name = f'data_iss_età_{out_date}.csv'
df_1.to_csv(out_name, encoding='utf-8-sig')
