# %% [markdown]
# ## "Table 3" extraction from ISS weekly covid-19 reports
# https://www.epicentro.iss.it/coronavirus/sars-cov-2-sorveglianza-dati
#
# See example pdf:
# https://www.epicentro.iss.it/coronavirus/bollettino/Bollettino-sorveglianza-integrata-COVID-19_8-settembre-2021.pdf
#
# Requirements: Java 8+, Python 3.6+

# %%
from tabula import read_pdf
import pandas as pd
import numpy as np

# %% [markdown]
# Scaricare nella cartella dati il bollettino dell'ISS https://www.epicentro.iss.it/coronavirus/bollettino/Bollettino-sorveglianza-integrata-COVID-19_22-settembre-2021.pdf

# %%
# input file
in_file = 'bollettino-22set.pdf' # replace with pdf name

# report data
rep_date = pd.to_datetime('22/09/2021') # replace with report date

# ...and read the raw table
raw_tb = read_pdf(in_file, pages=19, stream=True) # set page containing table 3
raw_tb[0]
# Out:
#              Unnamed: 0     Unnamed: 1         Unnamed: 2      VACCINATI CON  \
# 0                GRUPPO  FASCIA DI ETÀ      NON VACCINATI                NaN
# 1                   NaN            NaN                NaN   CICLO INCOMPLETO
# 2                   NaN          12-39  6.122.626 (35,1%)  3.199.510 (18,4%)
# 3           Popolazione          40-59  4.469.554 (24,2%)   1.372.996 (7,4%)
# 4           (4/09/2021)          60-79  1.705.446 (12,6%)     422.136 (3,1%)
# 5                   NaN            80+     283.500 (6,2%)     101.926 (2,2%)
# 6                   NaN          12-39     49.207 (72,9%)      7.216 (10,7%)
# 7           Diagnosi di            NaN                NaN                NaN
# 8                   NaN          40-59     26.851 (57,9%)       3.406 (7,3%)
# 9            Sars-CoV-2            NaN                NaN                NaN
# 10         (20/08/2021-          60-79      8.275 (39,6%)         957 (4,6%)
# 11          19/09/2021)            80+        1.800 (25%)         156 (2,2%)
# 12                  NaN          12-39      1.646 (89,3%)          80 (4,3%)
# 13   Ospedalizzazioni**          40-59        2.539 (86%)         109 (3,7%)
# 14         (13/08/2021-            NaN                NaN                NaN
# 15          12/09/2021)          60-79      1.883 (66,3%)         129 (4,5%)
# 16                  NaN            80+        714 (36,2%)          49 (2,5%)
# 17  Ricoveri in Terapia          12-39         76 (93,8%)           1 (1,2%)
# 18          Intensiva**          40-59        300 (92,6%)           7 (2,2%)
# 19         (13/08/2021-          60-79        355 (76,2%)          16 (3,4%)
# 20          12/09/2021)            80+         44 (42,7%)           2 (1,9%)
# 21                  NaN          12-39         13 (81,2%)           1 (6,2%)
# 22            Decessi**          40-59        127 (85,8%)           5 (3,4%)
# 23         (30/07/2021-            NaN                NaN                NaN
# 24          29/08/2021)          60-79        399 (71,2%)          34 (6,1%)
# 25                  NaN            80+          338 (47%)          17 (2,4%)
#
#        VACCINATI CON.1
# 0                  NaN
# 1       CICLO COMPLETO
# 2    8.113.419 (46,5%)
# 3   12.596.107 (68,3%)
# 4   11.445.197 (84,3%)
# 5    4.177.484 (91,6%)
# 6       11.040 (16,4%)
# 7                  NaN
# 8       16.128 (34,8%)
# 9                  NaN
# 10      11.646 (55,8%)
# 11       5.236 (72,8%)
# 12          118 (6,4%)
# 13         304 (10,3%)
# 14                 NaN
# 15         827 (29,1%)
# 16       1.207 (61,3%)
# 17            4 (4,9%)
# 18           17 (5,2%)
# 19          95 (20,4%)
# 20          57 (55,3%)
# 21           2 (12,5%)
# 22          16 (10,8%)
# 23                 NaN
# 24         127 (22,7%)
# 25         364 (50,6%)

# %%
# keep the last and the third last column
columns_to_keep = raw_tb[0].columns[[-3,-1]]
to_exclude = '\((.*)|[^a-z-0-9]|\d+-\d+|\d+\+'

df = raw_tb[0][columns_to_keep].replace(to_exclude, '', regex=True).replace('', np.nan)
df = df.dropna(subset=columns_to_keep, how='all').fillna(0).astype(np.int64)
df.columns = ['Non vaccinati', 'Immunizzati']
df
# Out:
#     Non vaccinati  Immunizzati
# 2         6122626      8113419
# 3         4469554     12596107
# 4         1705446     11445197
# 5          283500      4177484
# 6           49207        11040
# 8           26851        16128
# 10           8275        11646
# 11           1800         5236
# 12           1646          118
# 13           2539          304
# 15           1883          827
# 16            714         1207
# 17             76            4
# 18            300           17
# 19            355           95
# 20             44           57
# 21             13            2
# 22            127           16
# 24            399          127
# 25            338          364

# %%
# get data
# sum value by age/event

step_ = 4 # groups (=5) are 4 rows (=20) distant (see foo.pdf)

results = [df[col][i:i+step_].sum() for i in np.arange(0, len(df)-step_+1, step_) for col in df.columns]
results
# Out:
# [12581126, 36332207, 86133, 44050, 6782, 2456, 775, 173, 877, 509]

# %%
# read the original general data csv from apalladi's repo
# https://github.com/apalladi/covid_vaccini_monitoraggio/tree/main/dati

date_parser = lambda x: pd.to_datetime(x, format='%Y/%m/%d')
url = 'https://raw.githubusercontent.com/apalladi/covid_vaccini_monitoraggio/main/dati/dati_ISS_complessivi.csv'
df_0 = pd.read_csv(url, sep=';', parse_dates=['data'], date_parser=date_parser, index_col='data')
df_0
# Out:
#             non vaccinati  vaccinati completo  casi non vaccinati  \
# data
# 2021-09-15       13334156            35599815               96900
# 2021-09-08       14507530            34292078              104890
# 2021-09-01       15656647            32287644              107937
# 2021-08-25       16708830            29628678              104405
# 2021-08-18       17568325            26501452               95261
# 2021-08-11       20322716            22345659               80585
# 2021-08-04       21289761            19570464               60267
# 2021-07-28       22879167            17389604               40729
# 2021-07-21       24745853            15384196               26284
# 2021-07-14       27065063            13929401               21089
#
#             casi vaccinati  ospedalizzati non vaccinati  \
# data
# 2021-09-15           44990                         6841
# 2021-09-08           43775                         6579
# 2021-09-01           40380                         5988
# 2021-08-25           33894                         5162
# 2021-08-18           24978                         4052
# 2021-08-11           18887                         3067
# 2021-08-04           12333                         2234
# 2021-07-28            7277                         1619
# 2021-07-21            3805                         1483
# 2021-07-14            2310                         1880
#
#             ospedalizzati vaccinati  terapia intensiva non vaccinati  \
# data
# 2021-09-15                     2331                              786
# 2021-09-08                     2118                              712
# 2021-09-01                     1788                              641
# 2021-08-25                     1349                              500
# 2021-08-18                      859                              334
# 2021-08-11                      627                              247
# 2021-08-04                      404                              169
# 2021-07-28                      280                              123
# 2021-07-21                      224                              117
# 2021-07-14                      240                              147
#
#             terapia intensiva vaccinati  decessi non vaccinati  \
# data
# 2021-09-15                          163                    770
# 2021-09-08                          157                    571
# 2021-09-01                          127                    383
# 2021-08-25                           95                    246
# 2021-08-18                           61                    177
# 2021-08-11                           34                    143
# 2021-08-04                           23                    128
# 2021-07-28                           16                    169
# 2021-07-21                            8                    250
# 2021-07-14                            7                    357
#
#             decessi vaccinati
# data
# 2021-09-15                405
# 2021-09-08                280
# 2021-09-01                187
# 2021-08-25                 92
# 2021-08-18                 48
# 2021-08-11                 34
# 2021-08-04                 34
# 2021-07-28                 38
# 2021-07-21                 46
# 2021-07-14                 68

# %%
# add the new row at the top of the df
df_0.loc[rep_date] = results
df_0.sort_index(ascending=False, inplace=True)
df_0
# Out:
#             non vaccinati  vaccinati completo  casi non vaccinati  \
# data
# 2021-09-22       12581126            36332207               86133
# 2021-09-15       13334156            35599815               96900
# 2021-09-08       14507530            34292078              104890
# 2021-09-01       15656647            32287644              107937
# 2021-08-25       16708830            29628678              104405
# 2021-08-18       17568325            26501452               95261
# 2021-08-11       20322716            22345659               80585
# 2021-08-04       21289761            19570464               60267
# 2021-07-28       22879167            17389604               40729
# 2021-07-21       24745853            15384196               26284
# 2021-07-14       27065063            13929401               21089
#
#             casi vaccinati  ospedalizzati non vaccinati  \
# data
# 2021-09-22           44050                         6782
# 2021-09-15           44990                         6841
# 2021-09-08           43775                         6579
# 2021-09-01           40380                         5988
# 2021-08-25           33894                         5162
# 2021-08-18           24978                         4052
# 2021-08-11           18887                         3067
# 2021-08-04           12333                         2234
# 2021-07-28            7277                         1619
# 2021-07-21            3805                         1483
# 2021-07-14            2310                         1880
#
#             ospedalizzati vaccinati  terapia intensiva non vaccinati  \
# data
# 2021-09-22                     2456                              775
# 2021-09-15                     2331                              786
# 2021-09-08                     2118                              712
# 2021-09-01                     1788                              641
# 2021-08-25                     1349                              500
# 2021-08-18                      859                              334
# 2021-08-11                      627                              247
# 2021-08-04                      404                              169
# 2021-07-28                      280                              123
# 2021-07-21                      224                              117
# 2021-07-14                      240                              147
#
#             terapia intensiva vaccinati  decessi non vaccinati  \
# data
# 2021-09-22                          173                    877
# 2021-09-15                          163                    770
# 2021-09-08                          157                    571
# 2021-09-01                          127                    383
# 2021-08-25                           95                    246
# 2021-08-18                           61                    177
# 2021-08-11                           34                    143
# 2021-08-04                           23                    128
# 2021-07-28                           16                    169
# 2021-07-21                            8                    250
# 2021-07-14                            7                    357
#
#             decessi vaccinati
# data
# 2021-09-22                509
# 2021-09-15                405
# 2021-09-08                280
# 2021-09-01                187
# 2021-08-25                 92
# 2021-08-18                 48
# 2021-08-11                 34
# 2021-08-04                 34
# 2021-07-28                 38
# 2021-07-21                 46
# 2021-07-14                 68

# %%
# save to a csv
df_0.to_csv('dati_ISS_complessivi.csv', sep=';')

# %%
# get data by age
ages = ['12-39', '40-59', '60-79', '80+']
results_ = {age: df[ages.index(age)::step_].stack().values for age in ages}
results_
# Out:
# {'12-39': array([6122626, 8113419,   49207,   11040,    1646,     118,      76,
#               4,      13,       2], dtype=int64),
#  '40-59': array([ 4469554, 12596107,    26851,    16128,     2539,      304,
#              300,       17,      127,       16], dtype=int64),
#  '60-79': array([ 1705446, 11445197,     8275,    11646,     1883,      827,
#              355,       95,      399,      127], dtype=int64),
#  '80+': array([ 283500, 4177484,    1800,    5236,     714,    1207,      44,
#              57,     338,     364], dtype=int64)}

# %%
# load dict as df
df_1 = pd.DataFrame(results_).T
df_1.columns = df_0.columns
df_1.index.rename('età', inplace=True)
df_1.head()
# Out:
#        non vaccinati  vaccinati completo  casi non vaccinati  casi vaccinati  \
# età
# 12-39        6122626             8113419               49207           11040
# 40-59        4469554            12596107               26851           16128
# 60-79        1705446            11445197                8275           11646
# 80+           283500             4177484                1800            5236
#
#        ospedalizzati non vaccinati  ospedalizzati vaccinati  \
# età
# 12-39                         1646                      118
# 40-59                         2539                      304
# 60-79                         1883                      827
# 80+                            714                     1207
#
#        terapia intensiva non vaccinati  terapia intensiva vaccinati  \
# età
# 12-39                               76                            4
# 40-59                              300                           17
# 60-79                              355                           95
# 80+                                 44                           57
#
#        decessi non vaccinati  decessi vaccinati
# età
# 12-39                     13                  2
# 40-59                    127                 16
# 60-79                    399                127
# 80+                      338                364

# %%
# save to csv
df_1.to_csv(f'data_iss_età_{rep_date.date()}.csv', sep=';')
